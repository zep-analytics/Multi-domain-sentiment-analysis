# %%
import pandas as pd

# %%
import os
path_to_data = "../sorted_data"
# path_to_processed_data = "processed"
dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        dirs.append(entry.path)
dirs
# Out:
# ['../sorted_data/music',
#  '../sorted_data/video',
#  '../sorted_data/health_&_personal_care',
#  '../sorted_data/jewelry_&_watches',
#  '../sorted_data/magazines',
#  '../sorted_data/electronics',
#  '../sorted_data/camera_&_photo',
#  '../sorted_data/tools_&_hardware',
#  '../sorted_data/office_products',
#  '../sorted_data/books',
#  '../sorted_data/automotive',
#  '../sorted_data/dvd',
#  '../sorted_data/grocery',
#  '../sorted_data/software',
#  '../sorted_data/beauty',
#  '../sorted_data/cell_phones_&_service',
#  '../sorted_data/gourmet_food',
#  '../sorted_data/kitchen_&_housewares',
#  '../sorted_data/toys_&_games',
#  '../sorted_data/sports_&_outdoors',
#  '../sorted_data/musical_instruments',
#  '../sorted_data/outdoor_living',
#  '../sorted_data/apparel',
#  '../sorted_data/baby',
#  '../sorted_data/computer_&_video_games']

# %%
# for i in dirs:
#     product_type = i.split('/')[-1]
#     print(product_type)
    
#     for entry in os.scandir(i):
#         print(entry.path)
#         with open(entry.path,'r', encoding='ISO-8859-1') as f:
#             data = f.read()

#         with open(entry.path, 'w') as f:
#             f.write("<root>\n" + data + "\n</root>")
#             f.close()
# Out:
# music
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/positive.review
# video
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/positive.review
# health_&_personal_care
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/positive.review
# jewelry_&_watches
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/positive.review
# magazines
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/positive.review
# electronics
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/positive.review
# camera_&_photo
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/positive.review
# tools_&_hardware
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/positive.review
# office_products
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/positive.review
# books
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/positive.review
# automotive
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/positive.review
# dvd
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/positive.review
# grocery
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/processed.review.balanced
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/processed.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/positive.review
# software
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/positive.review
# beauty
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/positive.review
# cell_phones_&_service
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/positive.review
# gourmet_food
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/positive.review
# kitchen_&_housewares
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/positive.review
# toys_&_games
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/positive.review
# sports_&_outdoors
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/positive.review
# musical_instruments
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/positive.review
# outdoor_living
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/positive.review
# apparel
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/positive.review
# baby
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/positive.review
# computer_&_video_games
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/positive.review

# %%
# import xml.etree.ElementTree as ET

# tree = ET.parse('/Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/unlabeled.review', parser = ET.XMLParser(encoding = 'iso-8859-5'))

# %%
# for i in dirs:
#     product_type = i.split('/')[-1]
#     print(product_type)
    
#     for entry in os.scandir(i):
#         print(entry.path)
#         with open(entry.path,'r', encoding='ISO-8859-1') as f:
#             data = f.read()
#             data = data.replace('&', '&amp;')

#         with open(entry.path, 'w') as f:
#             f.write(data)
#             f.close()
# Out:
# music
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/music/positive.review
# video
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/video/positive.review
# health_&_personal_care
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/health_&_personal_care/positive.review
# jewelry_&_watches
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/jewelry_&_watches/positive.review
# magazines
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/magazines/positive.review
# electronics
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/electronics/positive.review
# camera_&_photo
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/camera_&_photo/positive.review
# tools_&_hardware
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/tools_&_hardware/positive.review
# office_products
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/office_products/positive.review
# books
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/books/positive.review
# automotive
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/automotive/positive.review
# dvd
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/dvd/positive.review
# grocery
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/processed.review.balanced
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/processed.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/grocery/positive.review
# software
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/software/positive.review
# beauty
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/beauty/positive.review
# cell_phones_&_service
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/cell_phones_&_service/positive.review
# gourmet_food
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/gourmet_food/positive.review
# kitchen_&_housewares
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/kitchen_&_housewares/positive.review
# toys_&_games
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/toys_&_games/positive.review
# sports_&_outdoors
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/sports_&_outdoors/positive.review
# musical_instruments
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/musical_instruments/positive.review
# outdoor_living
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/outdoor_living/positive.review
# apparel
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/positive.review
# baby
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/baby/positive.review
# computer_&_video_games
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/unlabeled.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/.DS_Store
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/all.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/negative.review
# /Users/taraldesai/Desktop/unprocessed/sorted_data/computer_&_video_games/positive.review

# %%
import xml.etree.ElementTree as ET

tree = ET.parse('/Users/taraldesai/Desktop/unprocessed/sorted_data/apparel/unlabeled.review', parser = ET.XMLParser(encoding = 'iso-8859-5'))

# %%
root = tree.getroot()
cols = ["unique_id", "asin", "product_name", "product_type", "helpful", "rating", "title", "date", "reviewer", "reviewer_location", "review_text"]
rows = []
for i in root:
    unique_id = i.find("unique_id").text
    asin = i.find("asin").text
    product_name = i.find("product_name").text
    product_type = i.find("product_type").text
    helpful = i.find("helpful").text
    rating = i.find("rating").text
    title = i.find("title").text
    date = i.find("date").text
    reviewer = i.find("reviewer").text
    reviewer_location = i.find("reviewer_location").text
    review_text = i.find("review_text").text
    rows.append({"unique_id": unique_id,
                 "asin": asin,
                 "product_name": product_name,
                 "product_type": product_type,
                 "helpful": helpful, 
                 "rating": rating, 
                 "title": title, 
                 "date": date, 
                 "reviewer": reviewer, 
                 "reviewer_location": reviewer_location, 
                 "review_text": review_text})
df = pd.DataFrame(rows, columns=cols)
df.head()
# Out:
#                                            unique_id            asin  \
# 0  \nB00085FIPO:size_runs_big:j._gould_"south_paw...  \nB00085FIPO\n
# 1  \nB0007QCPAA:there_isn't_a_more_comfortable_te...  \nB0007QCPAA\n
# 2       \nB0008DJTL0:a_great_running_shoe:xinyu_li\n  \nB0008DJTL0\n
# 3  \nB00006LZYJ:delighted_to_have_the_same_conven...  \nB00006LZYJ\n
# 4      \nB000B5S85I:who_sewed_this?:lindolfo_meira\n  \nB000B5S85I\n
#
#                                         product_name product_type     helpful  \
# 0                    \n3-Pack Baby Shorts: Apparel\n  \napparel\n  \n1 of 1\n
# 1  \nadidas Men's Smith Millennium Tennis Shoe: A...  \napparel\n        \n\n
# 2  \nadidas Originals Men's Adi Speed Suede Runni...  \napparel\n  \n1 of 1\n
# 3      \nMelton Shoe by Johnston & Murphy: Apparel\n  \napparel\n  \n0 of 4\n
# 4  \nVintage Fatigue Style Cap (with or without S...  \napparel\n        \n\n
#
#     rating                                              title  \
# 0  \n4.0\n                                  \nSize runs big\n
# 1  \n5.0\n  \nThere isn't a more comfortable tennis/casual...
# 2  \n5.0\n                           \nA great running shoe\n
# 3  \n5.0\n  \nDelighted to have the same convenience to pu...
# 4  \n4.0\n                                \nWho sewed this?\n
#
#                     date                     reviewer  \
# 0       \nMay 18, 2006\n  \nJ. Gould "south_paw712"\n
# 1  \nNovember 13, 2005\n          \nHannibal Lector\n
# 2  \nNovember 14, 2006\n                 \nXinyu Li\n
# 3   \nNovember 4, 2002\n             \nPeter Ekanem\n
# 4   \nNovember 9, 2006\n           \nLindolfo Meira\n
#
#                 reviewer_location  \
# 0                          \nKY\n
# 1                      \nJersey\n
# 2                            \n\n
# 3  \nMonterey, CA United States\n
# 4     \nPorto Alegre, RS Brazil\n
#
#                                          review_text
# 0  \nMy son is now over 12lbs at 6 weeks and thes...
# 1  \nmade PERIOD!!. The leather on this shoe is g...
# 2  \nAdidas traditional running shoe, suede, nice...
# 3  \nThank you for these new line of offerings. S...
# 4  \nOkay, this cap is really stylish. But I thin...

# %%
for i in df.columns:
    df[i] = df[i].apply(lambda x : x.strip('\n'))
df.head()
# Out:
#                                            unique_id        asin  \
# 0   B00085FIPO:size_runs_big:j._gould_"south_paw712"  B00085FIPO
# 1  B0007QCPAA:there_isn't_a_more_comfortable_tenn...  B0007QCPAA
# 2           B0008DJTL0:a_great_running_shoe:xinyu_li  B0008DJTL0
# 3  B00006LZYJ:delighted_to_have_the_same_convenie...  B00006LZYJ
# 4          B000B5S85I:who_sewed_this?:lindolfo_meira  B000B5S85I
#
#                                         product_name product_type helpful  \
# 0                        3-Pack Baby Shorts: Apparel      apparel  1 of 1
# 1  adidas Men's Smith Millennium Tennis Shoe: App...      apparel
# 2  adidas Originals Men's Adi Speed Suede Running...      apparel  1 of 1
# 3          Melton Shoe by Johnston & Murphy: Apparel      apparel  0 of 4
# 4  Vintage Fatigue Style Cap (with or without Sta...      apparel
#
#   rating                                              title  \
# 0    4.0                                      Size runs big
# 1    5.0  There isn't a more comfortable tennis/casual shoe
# 2    5.0                               A great running shoe
# 3    5.0  Delighted to have the same convenience to purc...
# 4    4.0                                    Who sewed this?
#
#                 date                 reviewer           reviewer_location  \
# 0       May 18, 2006  J. Gould "south_paw712"                          KY
# 1  November 13, 2005          Hannibal Lector                      Jersey
# 2  November 14, 2006                 Xinyu Li
# 3   November 4, 2002             Peter Ekanem  Monterey, CA United States
# 4   November 9, 2006           Lindolfo Meira     Porto Alegre, RS Brazil
#
#                                          review_text
# 0  My son is now over 12lbs at 6 weeks and these ...
# 1  made PERIOD!!. The leather on this shoe is glo...
# 2  Adidas traditional running shoe, suede, nice t...
# 3  Thank you for these new line of offerings. Som...
# 4  Okay, this cap is really stylish. But I think ...

# %%
import lxml.etree
parser = lxml.etree.XMLParser(encoding='utf-8', recover=True)

# %%
import xml.etree.ElementTree as ET

# tree = ET.parse('/Users/taraldesai/Desktop/unprocessed/sorted_data/books/unlabeled.review', parser = parser)

# %%
def get_text(tree):
   root = tree.getroot()
   cols = ["unique_id", "asin", "product_name", "product_type", "helpful", "rating", "title", "date", "reviewer", "reviewer_location", "review_text"]
   rows = []
   for i in root:
       if i.find("unique_id") is not None:
           unique_id = i.find("unique_id").text
       else:
          unique_id = ""
       if i.find("asin") is not None:
           asin = i.find("asin").text
       else:
           asin = ""
       if i.find("product_name") is not None:
           product_name = i.find("product_name").text
       else:
           product_name = ""
       if i.find("product_type") is not None:
            product_type = i.find("product_type").text
       else:
            product_type = ""
       if i.find("helpful") is not None:
            helpful = i.find("helpful").text
       else:
            helpful = ""
       if i.find("rating") is not None:
            rating = i.find("rating").text
       else:
            rating = ""
       if i.find("title") is not None:
            title = i.find("title").text
       else:
            title = ""
       if i.find("date") is not None:
            date = i.find("date").text
       else:       
            date = ""
       if i.find("reviewer") is not None:
            reviewer = i.find("reviewer").text
       else:
            reviewer = ""
       if i.find("reviewer_location") is not None:
            reviewer_location = i.find("reviewer_location").text
       else:
            reviewer_location = ""
       if i.find("review_text") is not None:
            review_text = i.find("review_text").text
       else:
            review_text = ""
       rows.append({"unique_id": unique_id,
                    "asin": asin,
                    "product_name": product_name,
                    "product_type": product_type,
                    "helpful": helpful, 
                    "rating": rating, 
                    "title": title, 
                    "date": date, 
                    "reviewer": reviewer, 
                    "reviewer_location": reviewer_location, 
                    "review_text": review_text})
   return pd.DataFrame(rows, columns=cols)

# %%
def strip_line_breaks(df):
    for i in df.columns:
        df[i] = df[i].apply(lambda x : x.strip('\n'))
    return df

# %%
# path_to_data = "/Users/taraldesai/Desktop/unprocessed/sorted_data"
path_to_processed_data = "/Users/taraldesai/Desktop/unprocessed/processed"

# %%
import shutil
if os.path.exists(path_to_processed_data):
     shutil.rmtree(path_to_processed_data)
os.mkdir(path_to_processed_data)

# %%
processed_dirs = []
processed_file_names_dict = {}
for dir in dirs:
    product_type = dir.split('/')[-1]
    processed_file_names_dict[product_type] = []
    for entry in os.scandir(dir):
        tree = ET.parse(entry.path, parser = parser)
        df = get_text(tree)
        df = strip_line_breaks(df)
        
        if tree is not None:
            processed_folder = path_to_processed_data + '/' + product_type
            if not os.path.exists(processed_folder):
                os.makedirs(processed_folder)
                processed_dirs.append(processed_folder)
                print("Generating processed files in folder: ",processed_folder)
            processed_file_name = product_type + "_" + ((entry.path).split('/')[-1]).split('.review')[0] + ".csv"
            processed_file_path = processed_folder + "/" + processed_file_name
            df.to_csv(processed_file_path, index=False)
            processed_file_names_dict[product_type].append(processed_file_path)
# Out:
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/music
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/video
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/health_&_personal_care
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/jewelry_&_watches
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/magazines
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/electronics
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/camera_&_photo
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/tools_&_hardware
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/office_products
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/books
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/automotive
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/dvd
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/grocery
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/software
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/beauty
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/cell_phones_&_service
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/gourmet_food
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/kitchen_&_housewares
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/toys_&_games
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/sports_&_outdoors
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/musical_instruments
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/outdoor_living
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/apparel
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/baby
# Generating processed files in folder:  /Users/taraldesai/Desktop/unprocessed/processed/computer_&_video_games

# %%
processed_dirs
# Out:
# ['/Users/taraldesai/Desktop/unprocessed/processed/music',
#  '/Users/taraldesai/Desktop/unprocessed/processed/video',
#  '/Users/taraldesai/Desktop/unprocessed/processed/health_&_personal_care',
#  '/Users/taraldesai/Desktop/unprocessed/processed/jewelry_&_watches',
#  '/Users/taraldesai/Desktop/unprocessed/processed/magazines',
#  '/Users/taraldesai/Desktop/unprocessed/processed/electronics',
#  '/Users/taraldesai/Desktop/unprocessed/processed/camera_&_photo',
#  '/Users/taraldesai/Desktop/unprocessed/processed/tools_&_hardware',
#  '/Users/taraldesai/Desktop/unprocessed/processed/office_products',
#  '/Users/taraldesai/Desktop/unprocessed/processed/books',
#  '/Users/taraldesai/Desktop/unprocessed/processed/automotive',
#  '/Users/taraldesai/Desktop/unprocessed/processed/dvd',
#  '/Users/taraldesai/Desktop/unprocessed/processed/grocery',
#  '/Users/taraldesai/Desktop/unprocessed/processed/software',
#  '/Users/taraldesai/Desktop/unprocessed/processed/beauty',
#  '/Users/taraldesai/Desktop/unprocessed/processed/cell_phones_&_service',
#  '/Users/taraldesai/Desktop/unprocessed/processed/gourmet_food',
#  '/Users/taraldesai/Desktop/unprocessed/processed/kitchen_&_housewares',
#  '/Users/taraldesai/Desktop/unprocessed/processed/toys_&_games',
#  '/Users/taraldesai/Desktop/unprocessed/processed/sports_&_outdoors',
#  '/Users/taraldesai/Desktop/unprocessed/processed/musical_instruments',
#  '/Users/taraldesai/Desktop/unprocessed/processed/outdoor_living',
#  '/Users/taraldesai/Desktop/unprocessed/processed/apparel',
#  '/Users/taraldesai/Desktop/unprocessed/processed/baby',
#  '/Users/taraldesai/Desktop/unprocessed/processed/computer_&_video_games']

# %% [markdown]
# Music

# %%
for i in processed_file_names_dict['music']:
    print(i)
# Out:
# /Users/taraldesai/Desktop/unprocessed/processed/music/music_unlabeled.csv
# /Users/taraldesai/Desktop/unprocessed/processed/music/music_all.csv
# /Users/taraldesai/Desktop/unprocessed/processed/music/music_negative.csv
# /Users/taraldesai/Desktop/unprocessed/processed/music/music_positive.csv

# %%
df_music_all = pd.read_csv(processed_file_names_dict['music'][1])

# %%
df_music_all.shape
# Out:
# (17030, 11)

# %%
df_music_unlabeled = pd.read_csv(processed_file_names_dict['music'][0])

# %%
df_music_unlabeled.shape
# Out:
# (1, 11)

# %%
df_music_positive = pd.read_csv(processed_file_names_dict['music'][3])

# %%
df_music_positive.shape
# Out:
# (1000, 11)

# %%
df_music_negative = pd.read_csv(processed_file_names_dict['music'][2])

# %%
df_music_negative.shape
# Out:
# (1000, 11)

# %%
df_music_all.head(50)
# Out:
#                                             unique_id        asin  \
# 0           B00004YWGC:what_can_i_say?:ms._aj_"right"  B00004YWGC
# 1        B000621498:not_quite_ready_for_prime_time.:g  B000621498
# 2    B0000AQS1A:disapointment:super_dave_"super_dave"  B0000AQS1A
# 3               B000F4TM6Y:ooo_lord:j._mitchell_"jim"  B000F4TM6Y
# 4               B000E3K3BY:boo_them_off_stage.:kurupt  B000E3K3BY
# 5   B000BJ7CCY:what!_ja_who?_can't_be!:a._lawson_"...  B000BJ7CCY
# 6   B00005K9R0:answers_for_songs:steve_franco_"steve"  B00005K9R0
# 7   B000066JEM:ben_gibbard_has_grown_a_lot_as_a_so...  B000066JEM
# 8   B000CQQHQS:not_the_music_from_this_movie:micha...  B000CQQHQS
# 9                B00099HFKK:are_you_kidding_me?:micah  B00099HFKK
# 10  B0000041E4:stick_to_the_movie,_that_was_a_trea...  B0000041E4
# 11  B00000C28J:no_such_thing_as_a_bad_cheap_trick_...  B00000C28J
# 12  B00000EIRP:arrive_all_over_you_by_danielle_bri...  B00000EIRP
# 13  B0000E1W27:stewart_is_clueless_with_the_standa...  B0000E1W27
# 14  B000EGEJMK:no_good_at_all:michael_quiroz_"m_i_...  B000EGEJMK
# 15  B00000IL29:it's_okay_not_to_like_this.:silverbear  B00000IL29
# 16  B0002SPQ3Q:talented?_what?:charlie_brown_"char...  B0002SPQ3Q
# 17  B000F3AAUW:not_crazy_about_it.:lee_ann_carter_...  B000F3AAUW
# 18                              B0009SCVTG:whack:mgib  B0009SCVTG
# 19  B00031TX8G:all_lil_jon_fans_are_dumb_as_hell!!...  B00031TX8G
# 20  B000063COL:oh_please:l._parafinik_"le_petite_r...  B000063COL
# 21  B00004Z42R:he_ca_nsing,_but_he_doesn't_seem_to...  B00004Z42R
# 22  B0002DRE3Q:boring:a._gershaw_"library_cd_borro...  B0002DRE3Q
# 23  B0000001O7:the_rockford_files.....and_where_di...  B0000001O7
# 24          B000FFL3B0:buy_'show'_instead:j._christou  B000FFL3B0
# 25  B000FFL3B0:"getting_somewhere"_goes_nowhere:jo...  B000FFL3B0
# 26  B000GY73IC:limp_melodies_and_so-so_songwriting...  B000GY73IC
# 27           B0001ZMCWS:one_good_song:john_c._collins  B0001ZMCWS
# 28  B000001EEA:clapton_suck:metallica_rocks_really...  B000001EEA
# 29     B00065GHWE:dissapointing:m._hawthorn_"markdek"  B00065GHWE
# 30  B000E0OFQQ:more_producer-driven_than_artist-dr...  B000E0OFQQ
# 31  B00009V7UR:should_be_thrown_in_the_incinerator...  B00009V7UR
# 32    B00005Y228:quite_unthoughtful:madeline_hartwell  B00005Y228
# 33  B000AMJDOC:childish_things_misses_and_tires:ta...  B000AMJDOC
# 34         B000063DS1:the_last_schmaltz:nuclear_snake  B000063DS1
# 35  B00005Q4JH:whatever_happened_to_quality_contro...  B00005Q4JH
# 36    B000ECX0UQ:40_water?_naw_kid_40_piss!!!!:kurupt  B000ECX0UQ
# 37             B0000063EY:painful_for_adults:a._lynch  B0000063EY
# 38     B000GFLE86:too_bad_madeleine.:n._protonotarios  B000GFLE86
# 39  B0009R1T7M:recycled_goods:ian_mahuron_"music_g...  B0009R1T7M
# 40  B000002LAP:disappointing_effort_from_an_otherw...  B000002LAP
# 41        B000GFLAI0:...theft__?:d._hyde_"david_hyde"  B000GFLAI0
# 42              B00079GCEC:please_make_it_stop!:tally  B00079GCEC
# 43         B00005LMBK:demon_days_is_better:a_reviewer  B00005LMBK
# 44                  B0009E32HA:dork_music:chase_kruse  B0009E32HA
# 45    B000092Q7L:lyke_omg!!!!:the_strapping_young_lad  B000092Q7L
# 46  B000025Z9I:dreadful!:rusty_kransky_"rusty_kran...  B000025Z9I
# 47       B00004WJZE:very_dissapointed:meghan_engstrom  B00004WJZE
# 48  B000AV2GCE:mediocre_jazz_recorded_in_mono:m._u...  B000AV2GCE
# 49   B0000AQS48:so_sick_of_this...:may_bay_"fjames23"  B0000AQS48
#
#                                          product_name product_type   helpful  \
# 0            Back For The First Time: Music: Ludacris        music   1 of 13
# 1   Things Aren't So Beautiful Now: Music: A Thorn...        music    1 of 2
# 2                     Chicken N Beer: Music: Ludacris        music    1 of 2
# 3                       New Joc City: Music: Yung Joc        music    4 of 4
# 2      2.0                                      Disapointment
# 3      1.0                                           ooo lord
# 4      1.0                                Boo them off stage.
# 5      2.0                            What! Ja WHO? Can't be!
# 6      2.0                                  ANSWERS FOR SONGS
# 7      2.0       Ben Gibbard has grown a lot as a songwriter.
# 8      1.0                      Not the music from this movie
# 9      1.0                                are you kidding me?
# 10     1.0              Stick To The Movie, THAT was a treat!
# 11     2.0  No such thing as a bad Cheap Trick album is st...
# 12     1.0          Arrive all over you by Danielle Brisebois
# 13     1.0            Stewart is clueless with the standards!
# 14     1.0                                     No Good At All
# 15     2.0                        It's okay not to like this.
# 16     1.0                                    talented? what?
# 17     2.0                                Not crazy about it.
# 18     2.0                                              whack
# 19     1.0               All Lil Jon Fans Are Dumb As Hell!!!
# 20     1.0                                          Oh please
# 21     1.0   He ca nsing, but he doesn't seem to have a style
# 22     2.0                                             Boring
# 23     2.0  The ROCKFORD FILES.....and where did the jazz go?
# 24     2.0                                 Buy 'Show' instead
# 25     2.0                   "Getting Somewhere" goes nowhere
# 26     2.0                Limp Melodies and So-So Songwriting
# 27     2.0                                      One good song
# 28     1.0                                       clapton suck
# 29     1.0                                      Dissapointing
# 30     2.0            More Producer-Driven Than Artist-Driven
# 31     1.0               Should be thrown in the incinerator.
# 32     1.0                                 Quite unthoughtful
# 33     2.0                   Childish Things Misses and Tires
# 34     2.0                                  The Last Schmaltz
# 35     2.0              Whatever happened to quality control?
# 36     1.0                      40 water? Naw kid 40 piss!!!!
# 37     1.0                                 Painful for Adults
# 38     2.0                                 Too bad Madeleine.
# 39     1.0                                     Recycled goods
# 40     2.0   Disappointing effort from an otherwise solid act
# 41     1.0                                        ...theft  ?
# 42     1.0                               Please Make It Stop!
# 43     2.0                               Demon Days is better
# 44     1.0                                         Dork music
# 45     1.0                                       LYKE OMG!!!!
# 46     1.0                                          Dreadful!
# 47     1.0                                  Very dissapointed
# 48     2.0                     Mediocre jazz recorded in MONO
# 49     1.0                                 So Sick Of This...
#
#                   date                                   reviewer  \
# 0          May 4, 2006                             Ms. AJ "Right"
# 1          May 8, 2006                                          g
# 2         July 1, 2006                    Super Dave "Super Dave"
# 3      October 6, 2006                          J. Mitchell "jim"
# 4          May 8, 2006                                     kurupt
# 5     November 7, 2006                        A. Lawson "G' Love"
# 6        July 24, 2006                       Steve Franco "Steve"
# 7     January 28, 2006                           Michael C. Boggs
# 8         May 18, 2006                        Michael R. Tilghman
# 9       August 7, 2005                                      Micah
# 10       July 24, 2006                                tom  george
# 11   December 21, 2005                          Ricahrd A. Salzer
# 12       June 13, 2002                                liana roche
# 13    October 28, 2006                                   Johnny G
# 14       April 9, 2006               Michael Quiroz "M I K E - Q"
# 15   February 15, 2006                                 Silverbear
# 16   November 19, 2004                    Charlie Brown "Charlie"
# 17    November 9, 2006       Lee Ann Carter "advertising goddess"
# 18  September 16, 2006                                       MgiB
# 19   September 2, 2006                         Jackson Braybrooks
# 20  September 22, 2005            L. Parafinik "le petite rocker"
# 21   December 12, 2003                               billy-da-kid
# 22   November 29, 2005           A. Gershaw "Library CD Borrower"
# 23   November 14, 2005                                  guitarguy
# 24      August 2, 2006                                J. Christou
# 25       July 11, 2006                             John S. Harris
# 26    October 10, 2006                 Rudy Palma "A Complex Guy"
# 27  September 27, 2005                            John C. Collins
# 28      August 4, 2006                METALLICA ROCKS REALLY HARD
# 29       July 21, 2005                      M. Hawthorn "Markdek"
# 30   February 25, 2006                         I. Rybinnik "Igor"
# 31    January 20, 2006  John Q. Public Television "PBS supporter"
# 32   February 27, 2006                          Madeline Hartwell
# 33    January 22, 2006                                  TAJ "Tom"
# 34    January 19, 2005                              Nuclear Snake
# 35  September 29, 2006              Kasper Michelsen "Alcibiades"
# 36     August 30, 2006                                     kurupt
# 37      April 13, 2006                                   A. Lynch
# 38   November 13, 2006                           N. Protonotarios
# 39     October 4, 2006                   Ian Mahuron "music geek"
# 40    November 9, 2004                            Darryl Da Silva
# 41   November 20, 2006                       D. HYDE "David Hyde"
# 42     August 25, 2006                                      Tally
# 43      April 19, 2006                                 A Reviewer
# 44       July 12, 2006                                Chase Kruse
# 45     August 24, 2006                    The Strapping Young Lad
# 46       June 14, 2001              Rusty Kransky "Rusty Kransky"
# 47  September 11, 2005                            Meghan Engstrom
# 48       July 30, 2006              M. Uysal "AddictedToTheRythm"
# 49        July 1, 2006                         May Bay "fjames23"
#
#                      reviewer_location  \
# 0                 North Carolina,  USA
# 1                        san francisco
# 2                        Knoxville, TN
# 3                                  FLA
# 4                              chicago
# 5                        RIP CITY, ATL
# 6                        Illinois, USA
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                            wash. DC
# 11           Chesapeake, Virginia, USA
# 12             miami, fl United States
# 13            New Jersey United States
# 14                           Tulsa, Ok
# 15                                 NaN
# 16                                 NaN
# 17  North Charleston, SC United States
# 18                             Slc, UT
# 19                                 NaN
# 20                     Minneapolis, Mn
# 21                      masculine side
# 22                          Boston, MA
# 23                          everywhere
# 24                    Ground Zero, NYC
# 25           Memphis, TN United States
# 26                                  NJ
# 27                         Suwanee, GA
# 28                                  SF
# 29                     Birmingham U.K.
# 30          Brooklyn, NY United States
# 31                                 USA
# 32               Sussex United Kingdom
# 33                 Los Angeles, CA USA
# 34                       Arlington, VA
# 35                Copenhagen, Denmark.
# 36                             chicago
# 37                             Florida
# 38                                 NaN
# 39               Coeur d'Alene, ID USA
# 40                  or at least apathy
# 41                      United Kingdom
# 42                                 NaN
# 43                                 USA
# 44                                 NaN
# 45                              Wacken
# 46         Greenport, NY United States
# 47            Duluth, MN United States
# 48                        Phoenix - AZ
# 49                       Colorado, USA
#
#                                           review_text
# 0   I've always held the philosophy you are what y...
# 1   someone get this band a producer and put them ...
# 2   Tihs Album is not all that good when it came o...
# 3   this industry is "goin down"  \n\nu call this ...
# 4   I'm sorry but the guy below me doesn't know mu...
# 5   This is not what I expected from such a gifted...
# 6   Ok, so the song playing when Brian goes and we...
# 7   There are 2 really good songs on here.  The fi...
# 8   This is not the music from the movie. This pur...
# 9   it is beyond me that a record label would put ...
# 10  Get's one star in appreciation of the technici...
# 11  Cheap Trick's second album is very disappointi...
# 12  After months of searching, I found the out of ...
# 13  Listening to the Standards being sung by Rod S...
# 14  Completely worthless! If you liked the film, g...
# 15  "Maiden Voyage" appears on innumerable lists o...
# 16  How can he be such an enormous talent when all...
# 17  Might just be me--but this is one of those CD'...
# 18  I'm an avid tony yayo fan, but this album just...
# 19  I can't believe rubbish like this goes platinu...
# 20  I love love tegan and sara and when I found ou...
# 21  Before you get all worked up, let me say that ...
# 22  Many albums, including this one, have the prob...
# 23  Sounds like the background music used in the 7...
# 24  Wow, did someone slip the wrong CD into my jew...
# 25  I really really really really like Allison Moo...
# 26  Now on their sixth studio album (and second on...
# 27  I was disappointed with the album as a whole. ...
# 28  Layla is one of the most overrated songs of al...
# 29  Having watched most, if not all of John Waters...
# 30  I think India is one of the most talented arti...
# 31  Oh, this is pure adult garbage all right.\n\nI...
# 32  I purchased a copy of this album after a sugge...
# 33  Mcmurtrys new album really disappoints.  I am ...
# 34  Is there anything more sanctimonious than film...
# 35  Michael Jackson is one of the most gifted song...
# 36  I felt like I was taking a piss on myself the ...
# 37  If any kid music annoys you, this CD is NOT fo...
# 38   I loved '' careless love`` and saw Madeleine ...
# 39  Having listened to Steven's previous albums, G...
# 40  I wanted to like BROTHERHOOD, for the simple r...
# 41  Why is Dylan taking sole credit on an album fe...
# 42  Man, can she get anymore stupid and talentless...
# 43  I first became a fan of the Gorillaz with thei...
# 44  Ok, booty rap was good in the 90's, when it wa...
# 45  I LUV FALL OUT BOY!!!!!!!!!\n\nAWL SONGS GET 1...
# 46  I don't understand the previous reviews - I fo...
# 47  After reading her excellent Halloween book, I ...
# 48  Neither the Amazon review or any of the custom...
# 49  I don't want to hear any more of their music o...

# %%
df_music_positive.head()
# Out:
#                                            unique_id        asin  \
# 0  B00008QS9V:it's_a_mighty_wind_a_blowin'!:carla...  B00008QS9V
# 1  B00005JJ04:sometime_tuesday_morning_defies_des...  B00005JJ04
# 2              B0002W4SGS:atreyu_jr:hellrun_"dustin"  B0002W4SGS
# 3         B000FILW86:a_man_of_my_word...:neoprog_ran  B000FILW86
# 4       B000BJ7CCY:well_done:urbanmusicfan296_"joel"  B000BJ7CCY
#
#                                        product_name product_type helpful  \
# 0  A Mighty Wind: The Album: Music: Various Artists        music     NaN
# 1        Sometime Tuesday Morning: Music: Johnny A.        music  4 of 4
# 2           The Caitiff Choir: Music: It Dies Today        music  0 of 1
# 3                      Rockford: Music: Cheap Trick        music  0 of 1
# 4                    Ghetto Classics: Music: Jaheim        music     NaN
#
#    rating                                        title               date  \
# 0     5.0                It's a Mighty Wind a blowin'!       July 5, 2006
# 1     5.0  Sometime Tuesday Morning defies description        May 3, 2005
# 2     5.0                                    atreyu JR      June 12, 2006
# 3     4.0                          A man of my word...  November 13, 2006
# 4     4.0                                    well done      April 7, 2006
#
#                                     reviewer         reviewer_location  \
# 0  Carla J. Dinsmore "Acoustic music junkie"        Wilmington, DE USA
# 1                                 Tim Withee  Auburn, WA United States
# 2                           hellrun "dustin"                 wisconsin
# 3                                NEOPROG RAN                EL PASO TX
# 4                    urbanmusicfan296 "Joel"                 LOUISIANA
#
#                                          review_text
# 0  This is a wonderful album, that evokes memorie...
# 1  On one hand, this CD is a straight ahead instr...
# 2  this band reminds me of the thrill i first got...
# 3  Like I said I would, I finally got around to p...
# 4  Ok good CD. im not suprised. Ok jaheim may not...

# %%
df_books = pd.read_csv(processed_file_names_dict['books'][1])
df_books.head()
# Out:
#                                            unique_id        asin  \
# 0  0743518144:ok~_but_i_think_the_keirsey_temperm...  0743518144
# 1  0895261715:repellent_sale_of_conservativism:e....  0895261715
# 2  0787978949:i_had_a_bad_feeling_about_this!__an...  0787978949
# 3     055380121X:lost_credability,_quickly!!:chalupa  055380121X
# 4                 0521662559:poorly_written:"dunner"  0521662559
#
#                                         product_name product_type   helpful  \
# 0  Now, Discover Your Strengths: Books: Marcus Bu...        books    7 of 8
# 1  The Conservative Mind: From Burke to Eliot: Bo...        books  32 of 95
# 2  Christian Wisdom of the Jedi Masters: Books: D...        books   6 of 12
# 3  The Wisdom of Menopause: Creating Physical and...        books  12 of 15
# 4  The Creation of America: Through Revolution to...        books   6 of 22
#
#    rating                                              title  \
# 0     2.0  Ok~ but I think the Keirsey Temperment Test is...
# 1     2.0                   Repellent Sale of Conservativism
# 2     1.0  I had a bad feeling about this!  And I was right!
# 3     2.0                        Lost Credability, QUICKLY!!
# 4     2.0                                     Poorly written
#
#                  date              reviewer       reviewer_location  \
# 0  September 10, 2006  Jen "the truthsayer"                 DE, USA
# 1     August 18, 2005         E. David Swan  South Euclid, Ohio USA
# 2    December 4, 2005                 Z. Fu            New York, NY
# 3       July 10, 2005               Chalupa      Central California
# 4    October 16, 2000              "dunner"      Washington, DC USA
#
#                                          review_text
# 0  This book has its good points. If anything, it...
# 1  The fatalistic view of Conservativism is expre...
# 2  I was intrigued by the title, which supposedly...
# 3  I admit, I haven't finished this book.  A frie...
# 4  I tried reading this book but found it so turg...

# %% [markdown]
# <h3>Cleaning of Apparel category</h3>

# %%
import re
import spacy

# %%
df_apparel = pd.read_csv(processed_file_names_dict['apparel'][1])
df_apparel.head()
# Out:
#                                            unique_id        asin  \
# 0         B000AN11UA:disappointed:c._tina_"ctina401"  B000AN11UA
# 1  B000AN11UA:cute_but_way_disappointing:katherin...  B000AN11UA
# 2  B000B5S85I:camo_fatigue_hat.:virgie_l._olson-j...  B000B5S85I
# 3  B000B5S85I:what's_next?__the_swastika??:the_du...  B000B5S85I
# 4          B00007LBZR:buyer_beware:david_s._schwartz  B00007LBZR
#
#                                         product_name product_type   helpful  \
# 0  Incase Limited Edition iPod Case - "Fleur" Sig...      apparel    3 of 3
# 1  Incase Limited Edition iPod Case - "Fleur" Sig...      apparel    3 of 5
# 2  Vintage Fatigue Style Cap (with or without Sta...      apparel    0 of 1
# 3  Vintage Fatigue Style Cap (with or without Sta...      apparel   3 of 12
# 4        Mens Collar Stays for Dress Shirts: Apparel      apparel  19 of 21
#
#    rating                         title              date  \
# 0     1.0                  disappointed    March 10, 2006
# 1     1.0    Cute But Way Disappointing  January 13, 2006
# 2     2.0             Camo Fatigue hat.  November 3, 2006
# 3     1.0  What's next?  The swastika??     July 30, 2006
# 4     1.0                  Buyer Beware    April 20, 2005
#
#                           reviewer      reviewer_location  \
# 0               C. Tina "Ctina401"             Woonsocket
# 1             Katherine M. Perkins       Pasadena, CA USA
# 2  Virgie L. Olson-jochum "Virgie"           Racine ,Wi..
# 3     The Dutchman "Dutch Schultz"              Cleveland
# 4                David S. Schwartz  Long Island, New York
#
#                                          review_text
# 0  I want to start by saying Fred Flare- shipped ...
# 1  I have to say that I was disappointed when I o...
# 2  I am sorry but I did not like it nor will I we...
# 3  A red star!?!?  I bet this won't sell well in ...
# 4  Perhaps it is my own fault for not reading mor...

# %%
df_apparel.isnull().sum()
# Out:
# unique_id               0
# asin                    0
# product_name            0
# product_type            0
# helpful              4179
# rating                  0
# title                   0
# date                    8
# reviewer              133
# reviewer_location    2152
# review_text             0
# dtype: int64

# %%
df_apparel = df_apparel.dropna()
df_apparel.isnull().sum()
# Out:
# unique_id            0
# asin                 0
# product_name         0
# product_type         0
# helpful              0
# rating               0
# title                0
# date                 0
# reviewer             0
# reviewer_location    0
# review_text          0
# dtype: int64

# %% [markdown]
# <h3> Remove product type from product_name in each row </h3>

# %%
df_apparel['product_name'] = df_apparel['product_name'].str.replace(': Apparel','')
df_apparel.head(30)
# Out:
#                                             unique_id        asin  \
# 0          B000AN11UA:disappointed:c._tina_"ctina401"  B000AN11UA
# 1   B000AN11UA:cute_but_way_disappointing:katherin...  B000AN11UA
# 2   B000B5S85I:camo_fatigue_hat.:virgie_l._olson-j...  B000B5S85I
# 3   B000B5S85I:what's_next?__the_swastika??:the_du...  B000B5S85I
# 4           B00007LBZR:buyer_beware:david_s._schwartz  B00007LBZR
# 6                   B0006ZAZPE:design_flaw:raven_weng  B0006ZAZPE
# 7              B0006ZAV4O:suit_was_too_small:xin_meng  B0006ZAV4O
# 8    B00012BBB4:swim_suit_grab_bag:f._moore_"montana"  B00012BBB4
# 11              B00085FIRW:awful!:amy_"mama_to_twins"  B00085FIRW
# 13  B000651E5O:second_one_also_gave_up_on_me_at_th...  B000651E5O
# 14    B000651E5O:lambskin_leather_belt_bag:a._fischer  B000651E5O
# 17       B0009OTGE8:bealls_of_florida:allen_m._sumner  B0009OTGE8
# 19                  B0006ZAZPE:design_flaw:raven_weng  B0006ZAZPE
# 20             B0006ZAV4O:suit_was_too_small:xin_meng  B0006ZAV4O
# 21   B00012BBB4:swim_suit_grab_bag:f._moore_"montana"  B00012BBB4
# 22  B000F1OAFU:champion_cotton_tagless_tee_x-large...  B000F1OAFU
# 23  B000AN11UA:cute_but_way_disappointing:katherin...  B000AN11UA
# 26              B00085FIRW:awful!:amy_"mama_to_twins"  B00085FIRW
# 28  B000651E5O:second_one_also_gave_up_on_me_at_th...  B000651E5O
# 30          B00007LBZR:buyer_beware:david_s._schwartz  B00007LBZR
# 32       B0009OTGE8:bealls_of_florida:allen_m._sumner  B0009OTGE8
# 33                   B0009OTGE8:worst_quality:lochank  B0009OTGE8
# 35  B000B5S85I:camo_fatigue_hat.:virgie_l._olson-j...  B000B5S85I
# 36  B000B5S85I:what's_next?__the_swastika??:the_du...  B000B5S85I
# 38  B000NHTCMM:created_for_a_dance_studio,_not_for...  B000NHTCMM
# 39  B00064VKB8:embassy_leather_products_are_sub-pa...  B00064VKB8
# 40  B000EZXS32:cute_shoe_but_not_practical:taheera...  B000EZXS32
# 44                    B0006L52A6:bad_design:l._clerge  B0006L52A6
# 45         B0007ZA0V2:passport_cover:kathleen_a._lyon  B0007ZA0V2
# 47  B000F195GY:not_meant_for_a_thin_6-year_old!:sj...  B000F195GY
#
#                                          product_name product_type   helpful  \
# 0   Incase Limited Edition iPod Case - "Fleur" Sig...      apparel    3 of
# 28  I bought two of these bags so far. both have f...
# 30  Perhaps it is my own fault for not reading mor...
# 32  The shirt fits well, good style, good shirt.  ...
# 33  I wore this shirt just once. It's almost trans...
# 35  I am sorry but I did not like it nor will I we...
# 36  A red star!?!?  I bet this won't sell well in ...
# 38  I purchased these about 3 months ago.  They ha...
# 39  I purchased 3 different Embassy purses last De...
# 40  I purchased these shoes for my upcoming weddin...
# 44  Haven't worn it yet to test the quality howeve...
# 45  Not what I expected for the price and the colo...
# 47  Our 6-year old wants to be a policeman when he...

# %% [markdown]
# <h3>Lowercase</h3>

# %%
df_apparel['new_title'] = df_apparel['title'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df_apparel['new_title'].head()
# Out:
# 0                   disappointed
# 1     cute but way disappointing
# 2              camo fatigue hat.
# 3    what's next? the swastika??
# 4                   buyer beware
# Name: new_title, dtype: object

# %%
df_apparel['new_reviews'] = df_apparel['review_text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df_apparel['new_reviews'].head()
# Out:
# 0    i want to start by saying fred flare- shipped ...
# 1    i have to say that i was disappointed when i o...
# 2    i am sorry but i did not like it nor will i we...
# 3    a red star!?!? i bet this won't sell well in e...
# 4    perhaps it is my own fault for not reading mor...
# Name: new_reviews, dtype: object

# %% [markdown]
# <h3>Remove Punctuation</h3>

# %%
df_apparel['new_title'] = df_apparel['new_title'].str.replace('[^\w\s]','')
df_apparel['new_title'].head()
# Out:
# /var/folders/xr/q2_sc4pj5f92dt7k2r4k1s7c0000gp/T/ipykernel_3750/2568342041.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_apparel['new_title'] = df_apparel['new_title'].str.replace('[^\w\s]','')
# 0                  disappointed
# 1    cute but way disappointing
# 2              camo fatigue hat
# 3       whats next the swastika
# 4                  buyer beware
# Name: new_title, dtype: object

# %%
df_apparel['new_reviews'] = df_apparel['new_reviews'].str.replace('[^\w\s]','')
df_apparel['new_reviews'].head()
# Out:
# /var/folders/xr/q2_sc4pj5f92dt7k2r4k1s7c0000gp/T/ipykernel_3750/1498375492.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_apparel['new_reviews'] = df_apparel['new_reviews'].str.replace('[^\w\s]','')
# 0    i want to start by saying fred flare shipped t...
# 1    i have to say that i was disappointed when i o...
# 2    i am sorry but i did not like it nor will i we...
# 3    a red star i bet this wont sell well in easter...
# 4    perhaps it is my own fault for not reading mor...
# Name: new_reviews, dtype: object

# %% [markdown]
# <h3>Remove Emojis</h3>

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags 
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
df_apparel['new_title'] = df_apparel['new_title'].apply(lambda x: remove_emoji(x))
df_apparel['new_reviews'] = df_apparel['new_reviews'].apply(lambda x: remove_emoji(x))

# %% [markdown]
# <h3>Remove Stopwords</h3>

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import nltk
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
stop = stopwords.words('english')

df_apparel['new_title'] = df_apparel['title'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

df_apparel['new_reviews'] = df_apparel['new_reviews'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

df_apparel.head(20)
# Out:
#                                             unique_id        asin  \
# 0          B000AN11UA:disappointed:c._tina_"ctina401"  B000AN11UA
# 1   B000AN11UA:cute_but_way_disappointing:katherin...  B000AN11UA
# 2   B000B5S85I:camo_fatigue_hat.:virgie_l._olson-j...  B000B5S85I
# 3   B000B5S85I:what's_next?__the_swastika??:the_du...  B000B5S85I
# 4           B00007LBZR:buyer_beware:david_s._schwartz  B00007LBZR
# 3          red star bet wont sell well eastern europe
# 4   perhaps fault reading closely failing question...
# 6   ordered black one according photo provided sup...
# 7   suit small enough information available site c...
# 8   swim suit unsatisfactory looking didnt even tr...
# 11  body suits awful first saw really relieved fou...
# 13  bought two bags far failed plastic fastener on...
# 14  give order processing due receiving product wi...
# 17  shirt fits well good style good shirt bealls f...
# 19  ordered black one according photo provided sup...
# 20  suit small enough information available site c...
# 21  swim suit unsatisfactory looking didnt even tr...
# 22  small frame person short person work fine whit...
# 23  say disappointed opened package containing ipo...
# 26  body suits awful first saw really relieved fou...
# 28  bought two bags far failed plastic fastener on...
# 30  perhaps fault reading closely failing question...

# %% [markdown]
# <h3>Lemmatization</h3>

# %%
import en_core_web_sm

nlp = en_core_web_sm.load()

# %%
def space(comment):
    doc = nlp(comment)
    return " ".join([token.lemma_ for token in doc])
df_apparel['new_reviews']= df_apparel['new_reviews'].apply(space)
df_apparel.head(20)
# Out:
#                                             unique_id        asin  \
# 0          B000AN11UA:disappointed:c._tina_"ctina401"  B000AN11UA
# 1   B000AN11UA:cute_but_way_disappointing:katherin...  B000AN11UA
# 2   B000B5S85I:camo_fatigue_hat.:virgie_l._olson-j...  B000B5S85I
# 3   B000B5S85I:what's_next?__the_swastika??:the_du...  B000B5S85I
# 4           B00007LBZR:buyer_beware:david_s._schwartz  B00007LBZR
# 6                   B0006ZAZPE:design_flaw:raven_weng  B0006ZAZPE
# 7              B0006ZAV4O:suit_was_too_small:xin_meng  B0006ZAV4O
# 8    B00012BBB4:swim_suit_grab_bag:f._moore_"montana"  B00012BBB4
# 11              B00085FIRW:awful!:amy_"mama_to_twins"  B00085FIRW
# 13  B000651E5O:second_one_also_gave_up_on_me_at_th...  B000651E5O
# 14    B000651E5O:lambskin_leather_belt_bag:a._fischer  B000651E5O
# 17       B0009OTGE8:bealls_of_florida:allen_m._sumner  B0009OTGE8
# 19                  B0006ZAZPE:design_flaw:raven_weng  B0006ZAZPE
# 20             B0006ZAV4O:suit_was_too_small:xin_meng  B0006ZAV4O
# 21   B00012BBB4:swim_suit_grab_bag:f._moore_"montana"  B00012BBB4
# 22  B000F1OAFU:champion_cotton_tagless_tee_x-large...  B000F1OAFU
# 23  B000AN11UA:cute_but_way_disappointing:katherin...  B000AN11UA
# 26              B00085FIRW:awful!:amy_"mama_to_twins"  B00085FIRW
# 28  B000651E5O:second_one_also_gave_up_on_me_at_th...  B000651E5O
# 30          B00007LBZR:buyer_beware:david_s._schwartz  B00007LBZR
#
#                                          product_name product_type   helpful  \
# 0   Incase Limited Edition iPod Case - "Fleur" Sig...      apparel    3 of 3
# 1   Incase Limited Edition iPod Case - "Fleur" Sig...      apparel    3 of 5
# 2   Vintage Fatigue Style Cap (with or without Sta...      apparel    0 of 1
# 3   Vintage Fatigue Style Cap (with or without Sta...      apparel   3 of 12
# 4                  Mens Collar Stays for Dress Shirts      apparel  19 of 21
# 6           Speedo Women's Endurance Flyback Swimsuit      apparel    3 of 5
# 7   Speedo Women's Lycra Quantum Splice Solid Swim...      apparel    2 of 3
# 8                            TYR Grab bag Female Suit      apparel    2 of 2
# 11            4-Pack Lightweight Sleeveless Bodysuits      apparel  14 of 14
# 13            Maxam Genuine Lambskin Leather Belt Bag      apparel    1 of 1
# 14            Maxam Genuine Lambskin Leather Belt Bag      apparel    7 of 7
# 17  Bill Blass Men's Dress Shirt with Fashion Poin...      apparel    6 of 8
# 19          Speedo Women's Endurance Flyback Swimsuit      apparel    3 of 5
# 20  Speedo Women's Lycra Quantum Splice Solid Swim...      apparel    2 of 3
# 21                           TYR Grab bag Female Suit      apparel    2 of 3
# 22              Champion Cotton Tagless Tee - T-Shirt      apparel  16 of 18
# 23  Incase Limited Edition iPod Case - "Fleur" Sig...      apparel    3 of 5
#
# 6   I ordered the black one. According to the phot...
# 7   Suit was too small, not enough information ava...
# 8   the swim suit was so unsatisfactory looking th...
# 11  These body suits are awful! When I first saw t...
# 13  I bought two of these bags so far. both have f...
# 14  I give the order processing an A+ due to recei...
# 17  The shirt fits well, good style, good shirt.  ...
# 19  I ordered the black one. According to the phot...
# 20  Suit was too small, not enough information ava...
# 21  the swim suit was so unsatisfactory looking th...
# 22  If you are a small frame person or a short per...
# 23  I have to say that I was disappointed when I o...
# 26  These body suits are awful! When I first saw t...
# 28  I bought two of these bags so far. both have f...
# 30  Perhaps it is my own fault for not reading mor...
#
#                                         new_title  \
# 0                                    disappointed
# 1                      Cute But Way Disappointing
# 2                               Camo Fatigue hat.
# 3                     What's next? The swastika??
# 4                                    Buyer Beware
# 6                                     Design flaw
# 7                                      Suit small
# 8                              Swim suit grab bag
# 11                                         Awful!
# 13              second one also gave plastic clip
# 14                      Lambskin leather belt bag
# 17                                 Bealls Florida
# 19                                    Design flaw
# 20                                     Suit small
# 21                             Swim suit grab bag
# 22  Champion Cotton Tagless tee x-large white buy
# 23                     Cute But Way Disappointing
# 26                                         Awful!
# 28              second one also gave plastic clip
# 30                                   Buyer Beware
#
#                                           new_reviews
# 0   want start say fred flare ship product fast tr...
# 1   say disappoint open package contain ipod walle...
# 2             sorry like wear big look funny wish get
# 3      red star bet will not sell well eastern europe
# 4   perhaps fault read closely fail question somew...
# 6   order black one accord photo provide suppose b...
# 7   suit small enough information available site c...
# 8   swim suit unsatisfactory look do not even try ...
# 11  body suit awful first see really relieve find ...
# 13  buy two bag far fail plastic fastener one arm ...
# 14  give order processing due receive product with...
# 17  shirt fit well good style good shirt beall flo...
# 19  order black one accord photo provide suppose b...
# 20  suit small enough information available site c...
# 21  swim suit unsatisfactory look do not even try ...
# 22  small frame person short person work fine whit...
# 23  say disappoint open package contain ipod walle...
# 26  body suit awful first see really relieve find ...
# 28  buy two bag far fail plastic fastener one arm ...
# 30  perhaps fault read closely fail question somew...

# %% [markdown]
# <h3>The steps used to complete the preprocessing of data were:</h3>
# <ol>
# <li>Make text lowercase</li>
# <li>Remove punctuation</li>
# <li>Remove emoji’s</li>
# <li>Remove stopwords</li>
# <li>Lemmatization</li>
# </ol>

# %% [markdown]
# <h1>Combined cleaning of 4 categories, i.e., Apparel, Automotive, Baby and Beauty.</h1>

# %%
df_apparel_1 = pd.read_csv(processed_file_names_dict['apparel'][1])
df_automotive = pd.read_csv(processed_file_names_dict['automotive'][1])
df_baby = pd.read_csv(processed_file_names_dict['baby'][1])
df_beauty = pd.read_csv(processed_file_names_dict['beauty'][1])

# %%
df_combine = pd.concat([df_apparel_1, df_books, df_automotive, df_baby, df_beauty], ignore_index=True)
df_combine.head()
# Out:
#                                            unique_id        asin  \
# 0         B000AN11UA:disappointed:c._tina_"ctina401"  B000AN11UA
# 1  B000AN11UA:cute_but_way_disappointing:katherin...  B000AN11UA
# 2  B000B5S85I:camo_fatigue_hat.:virgie_l._olson-j...  B000B5S85I
# 3  B000B5S85I:what's_next?__the_swastika??:the_du...  B000B5S85I
# 4          B00007LBZR:buyer_beware:david_s._schwartz  B00007LBZR
#
#                                         product_name product_type   helpful  \
# 0  Incase Limited Edition iPod Case - "Fleur" Sig...      apparel    3 of 3
# 1  Incase Limited Edition iPod Case - "Fleur" Sig...      apparel    3 of 5
# 2  Vintage Fatigue Style Cap (with or without Sta...      apparel    0 of 1
# 3  Vintage Fatigue Style Cap (with or without Sta...      apparel   3 of 12
# 4        Mens Collar Stays for Dress Shirts: Apparel      apparel  19 of 21
#
#    rating                         title              date  \
# 0     1.0                  disappointed    March 10, 2006
# 1     1.0    Cute But Way Disappointing  January 13, 2006
# 2     2.0             Camo Fatigue hat.  November 3, 2006
# 3     1.0  What's next?  The swastika??     July 30, 2006
# 4     1.0                  Buyer Beware    April 20, 2005
#
#                           reviewer      reviewer_location  \
# 0               C. Tina "Ctina401"             Woonsocket
# 1             Katherine M. Perkins       Pasadena, CA USA
# 2  Virgie L. Olson-jochum "Virgie"           Racine ,Wi..
# 3     The Dutchman "Dutch Schultz"              Cleveland
# 4                David S. Schwartz  Long Island, New York
#
#                                          review_text
# 0  I want to start by saying Fred Flare- shipped ...
# 1  I have to say that I was disappointed when I o...
# 2  I am sorry but I did not like it nor will I we...
# 3  A red star!?!?  I bet this won't sell well in ...
# 4  Perhaps it is my own fault for not reading mor...

# %%
df_combine.isnull().sum()
# Out:
# unique_id               0
# asin                    0
# product_name            0
# product_type            0
# helpful              6566
# rating                  0
# title                   0
# date                   13
# reviewer              313
# reviewer_location    3819
# review_text             0
# dtype: int64

# %%
df_combine = df_combine.dropna()
df_combine.isnull().sum()
# Out:
# unique_id            0
# asin                 0
# product_name         0
# product_type         0
# helpful              0
# rating               0
# title                0
# date                 0
# reviewer             0
# reviewer_location    0
# review_text          0
# dtype: int64

# %%
df_combine['new_title'] = df_combine['title'].apply(lambda x: " ".join(x.lower() for x in x.split()))

df_combine['new_reviews'] = df_combine['review_text'].apply(lambda x: " ".join(x.lower() for x in x.split()))

df_combine['new_title'] = df_combine['new_title'].str.replace('[^\w\s]','')

df_combine['new_reviews'] = df_combine['new_reviews'].str.replace('[^\w\s]','')

df_combine['new_title'] = df_combine['new_title'].apply(lambda x: remove_emoji(x))

df_combine['new_reviews'] = df_combine['new_reviews'].apply(lambda x: remove_emoji(x))

df_combine['new_title'] = df_combine['title'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

df_combine['new_reviews'] = df_combine['new_reviews'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

df_combine['new_reviews']= df_combine['new_reviews'].apply(space)
# Out:
# /var/folders/xr/q2_sc4pj5f92dt7k2r4k1s7c0000gp/T/ipykernel_3750/3135036313.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_combine['new_title'] = df_combine['new_title'].str.replace('[^\w\s]','')
# /var/folders/xr/q2_sc4pj5f92dt7k2r4k1s7c0000gp/T/ipykernel_3750/3135036313.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_combine['new_reviews'] = df_combine['new_reviews'].str.replace('[^\w\s]','')

# %% [markdown]
# <h3>Title & Review cleaned</h3>

# %%
df_combine.head(50)
# Out:
#                                             unique_id        asin  \
# 0          B000AN11UA:disappointed:c._tina_"ctina401"  B000AN11UA
# 1   B000AN11UA:cute_but_way_disappointing:katherin...  B000AN11UA
# 2   B000B5S85I:camo_fatigue_hat.:virgie_l._olson-j...  B000B5S85I
# 3   B000B5S85I:what's_next?__the_swastika??:the_du...  B000B5S85I
# 4           B00007LBZR:buyer_beware:david_s._schwartz  B00007LBZR
# 6                   B0006ZAZPE:design_flaw:raven_weng  B0006ZAZPE
# 7              B0006ZAV4O:suit_was_too_small:xin_meng  B0006ZAV4O
# 8    B00012BBB4:swim_suit_grab_bag:f._moore_"montana"  B00012BBB4
# 11              B00085FIRW:awful!:amy_"mama_to_twins"  B00085FIRW
# 13  B000651E5O:second_one_also_gave_up_on_me_at_th...  B000651E5O
# 14    B000651E5O:lambskin_leather_belt_bag:a._fischer  B000651E5O
# 17       B0009OTGE8:bealls_of_florida:allen_m._sumner  B0009OTGE8
# 19                  B0006ZAZPE:design_flaw:raven_weng  B0006ZAZPE
# 20             B0006ZAV4O:suit_was_too_small:xin_meng  B0006ZAV4O
# 21   B00012BBB4:swim_suit_grab_bag:f._moore_"montana"  B00012BBB4
# 22  B000F1OAFU:champion_cotton_tagless_tee_x-large...  B000F1OAFU
# 23  B000AN11UA:cute_but_way_disappointing:katherin...  B000AN11UA
# 26              B00085FIRW:awful!:amy_"mama_to_twins"  B00085FIRW
# 28  B000651E5O:second_one_also_gave_up_on_me_at_th...  B000651E5O
# 30          B00007LBZR:buyer_beware:david_s._schwartz  B00007LBZR
# 32       B0009OTGE8:bealls_of_florida:allen_m._sumner  B0009OTGE8
# 33                   B0009OTGE8:worst_quality:lochank  B0009OTGE8
# 35  B000B5S85I:camo_fatigue_hat.:virgie_l._olson-j...  B000B5S85I
# 36  B000B5S85I:what's_next?__the_swastika??:the_du...  B000B5S85I
# 38  B000NHTCMM:created_for_a_dance_studio,_not_for...  B000NHTCMM
# 39  B00064VKB8:embassy_leather_products_are_sub-pa...  B00064VKB8
# 40  B000EZXS32:cute_shoe_but_not_practical:taheera...  B000EZXS32
# 44                    B0006L52A6:bad_design:l._clerge  B0006L52A6
# 45         B0007ZA0V2:passport_cover:kathleen_a._lyon  B0007ZA0V2
# 47  B000F195GY:not_meant_for_a_thin_6-year_old!:sj...  B000F195GY
# 49                  B0006ZT9EC:not_so_good...:s._king  B0006ZT9EC
# 50  B000FVBWYC:comfy_but_so_so_color_looks_differe...  B000FVBWYC
# 51  B0002FHIKS:poor_customer_service....:n._caldwe...  B0002FHIKS
# 52  B000A2LI6I:too_thin_to_keep_you_warm,_too_bulk...  B000A2LI6I
# 54  B000CFH1FU:adidas_men's_a3_gigaride_running_sh...  B000CFH1FU
# 59     B00009YPNN:don't_bother!:scharocks_"scharocks"  B00009YPNN
# 60  B00009YPNN:don't_waste_your_money,_big_busted_...  B00009YPNN
# 61  B000FTECGE:larger_than_i_expected:mistress_reb...  B000FTECGE
# 65                   B000J45DOU:disappointed:momandrn  B000J45DOU
# 68  B000IRHH8S:waste_of_money:j._parker_"satisfied...  B000IRHH8S
# 69      B000IRHH8S:a_bit_disappointed...:superflylinz  B000IRHH8S
# 70                    B000EJRX0W:too_small!:donna_gee  B000EJRX0W
# 73  B000G7Y9PO:morgans_long_johns_authenic_thermal...  B000G7Y9PO
# 77  B000ASBMAY:not_the_same_quality:qaiser_h._sidd...  B000ASBMAY
# 79             B0001YR25Q:sizes_run_small:angela_hall  B0001YR25Q
# 80  B000G2V59M:cute,_but_impossible_to_keep_on!:b....  B000G2V59M
# 81  B0006TP02S:cheap_for_a_reason_._._._:a._parker...  B0006TP02S
# 83       B0007MCPFY:not_made_in_italy:woodbill_"wzwz"  B0007MCPFY
# 85  B000FLXT1G:doesn't_warrant_a_1!:j._haertling_"...  B000FLXT1G
# 86    B000IZBDYO:don't_waste_your_money:m._antoinette  B000IZBDYO
#
#                                          product_name product_type   helpful  \
# 0   Incase Limited Edition iPod Case - "Fleur" Sig...      apparel    3 of
# 54                                 NC
# 59                                NYC
# 60                   Murrieta, CA USA
# 61                         Golden, CO
# 65                                 NY
# 68            Springfield Gardens, NY
# 69  Baltimore, Maryland United States
# 70                                 MD
# 73                             Oregon
# 77                             IL USA
# 79                      Georgetown KY
# 80                      United States
# 81    San Francisco, CA United States
# 83                       New York, NY
# 85                     Dallas, TX USA
# 86                southern california
#
#                                           review_text  \
# 0   I want to start by saying Fred Flare- shipped ...
# 1   I have to say that I was disappointed when I o...
# 2   I am sorry but I did not like it nor will I we...
# 3   A red star!?!?  I bet this won't sell well in ...
# 4   Perhaps it is my own fault for not reading mor...
# 6   I ordered the black one. According to the phot...
# 7   Suit was too small, not enough information ava...
# 8   the swim suit was so unsatisfactory looking th...
# 11  These body suits are awful! When I first saw t...
# 13  I bought two of these bags so far. both have f...
# 14  I give the order processing an A+ due to recei...
# 17  The shirt fits well, good style, good shirt.  ...
# 19  I ordered the black one. According to the phot...
# 20  Suit was too small, not enough information ava...
# 21  the swim suit was so unsatisfactory looking th...
# 22  If you are a small frame person or a short per...
# 23  I have to say that I was disappointed when I o...
# 26  These body suits are awful! When I first saw t...
# 28  I bought two of these bags so far. both have f...
# 30  Perhaps it is my own fault for not reading mor...
# 32  The shirt fits well, good style, good shirt.  ...
# 33  I wore this shirt just once. It's almost trans...
# 35  I am sorry but I did not like it nor will I we...
# 36  A red star!?!?  I bet this won't sell well in ...
# 38  I purchased these about 3 months ago.  They ha...
# 39  I purchased 3 different Embassy purses last De...
# 40  I purchased these shoes for my upcoming weddin...
# 44  Haven't worn it yet to test the quality howeve...
# 45  Not what I expected for the price and the colo...
# 47  Our 6-year old wants to be a policeman when he...
# 49  This "pillow" is an inflated "U" that fits aro...
# 50  Shoe is comfortable but the description says o...
# 51  Our company ordered these shirts from the Texa...
# 52  I purchased this item to keep my wife warm and...
# 54  These shoes look great but are horrible runnin...
# 59  I got this bra thinking it would be great for ...
# 60  I am a 38 FF, and I was hoping this would help...
# 61  This shirt was larger than I expected.  I got ...
# 65  I received the night gown, tried it on, and ac...
# 68  The shoes weren't the color that I wanted them...
# 69  ...the shoes weren't quite what I thought they...
# 70  These tops were cute, for my 7 & 10 year old n...
# 73  Not the best fabric, Scratchy and See thru. Yo...
# 77  SHOES WAS NOT EXCALTY THE SAME AS PIC SHOWN ON...
# 79  I actually had to send this back cause of the ...
# 80  These shoes were very cute, as I thought they ...
# 81  Very poor quality, falling apart at the seams....
# 83  If you see the description: made in Italy, be ...
# 85  So cheap, the seams weren't sewn up all the wa...
# 86  The photo is quite deceiving.  This suit is ma...
#
#                                             new_title  \
# 0                                        disappointed
# 1                          Cute But Way Disappointing
# 2                                   Camo Fatigue hat.
# 3                         What's next? The swastika??
# 4                                        Buyer Beware
# 6                                         Design flaw
# 7                                          Suit small
# 8                                  Swim suit grab bag
# 11                                             Awful!
# 13                  second one also gave plastic clip
# 14                          Lambskin leather belt bag
# 17                                     Bealls Florida
# 19                                        Design flaw
# 20                                         Suit small
# 21                                 Swim suit grab bag
# 22      Champion Cotton Tagless tee x-large white buy
# 23                         Cute But Way Disappointing
# 26                                             Awful!
# 28                  second one also gave plastic clip
# 30                                       Buyer Beware
# 32                                     Bealls Florida
# 33                                      Worst Quality
# 35                                  Camo Fatigue hat.
# 36                        What's next? The swastika??
# 38    Created dance studio, walking streets Manhattan
# 39                   Embassy Leather Products sub-par
# 40                                Cute shoe practical
# 44                                         Bad design
# 45                                     Passport Cover
# 47                         Not meant thin 6-year old!
# 49                                        Not good...
# 50                    Comfy color looks different Pic
# 51                          Poor Customer Service....
# 52             Too thin keep warm, bulky haul around.
# 54  adidas Men's a3 Gigaride Running Shoe,Cyber Me...
# 59                                      Don't Bother!
# 60                Don't waste money, big busted gals!
# 61                                  larger I expected
# 65                                       Disappointed
# 68                                        Waste money
# 69                                bit disappointed...
# 70                                         Too Small!
# 73               Morgans long johns Authenic Thermals
# 77                                        Not QUALITY
# 79                                    Sizes run small
# 80                          Cute, impossible keep on!
# 81                                 Cheap reason . . .
# 83                                     Not made Italy
# 85                                 Doesn't warrant 1!
# 86                                  Don't waste money
#
#                                           new_reviews
# 0   want start say fred flare ship product fast tr...
# 1   say disappoint open package contain ipod walle...
# 2             sorry like wear big look funny wish get
# 3      red star bet will not sell well eastern europe
# 4   perhaps fault read closely fail question somew...
# 6   order black one accord photo provide suppose b...
# 7   suit small enough information available site c...
# 8   swim suit unsatisfactory look do not even try ...
# 11  body suit awful first see really relieve find ...
# 13  buy two bag far fail plastic fastener one arm ...
# 14  give order processing due receive product with...
# 17  shirt fit well good style good shirt beall flo...
# 19  order black one accord photo provide suppose b...
# 20  suit small enough information available site c...
# 21  swim suit unsatisfactory look do not even try ...
# 22  small frame person short person work fine whit...
# 23  say disappoint open package contain ipod walle...
# 26  body suit awful first see really relieve find ...
# 28  buy two bag far fail plastic fastener one arm ...
# 30  perhaps fault read closely fail question somew...
# 32  shirt fit well good style good shirt beall flo...
# 33  wear shirt almost transparent worth even get free
# 35            sorry like wear big look funny wish get
# 36     red star bet will not sell well eastern europe
# 38  purchase 3 month ago little arch support littl...
# 39  purchase 3 different embassy purse last decemb...
# 40  purchase shoe upcoming wedding hard time walk ...
# 44  have not wear yet test quality however structu...
# 45  expect price color ship wrong even though cont...
# 47  6year old want policeman grow could wait get b...
# 49  pillow inflated u fit around neck one problem ...
# 50  shoe comfortable description say white white b...
# 51  company order shirt texas shirt company happy ...
# 52  purchase item keep wife warm cozy 12hour fligh...
# 54  shoe look great horrible running shoe sol soli...
# 59  get bra thinking would great rigorous sport 38...
# 60  38 ff hope would help hold run bra well 18 hou...
# 61  shirt large expect get 2x I m 1214 way big als...
# 65  receive night gown try actually hate build bra...
# 68  shoe be not color want cheap price quality goo...
# 69  shoe be not quite think would although 40 buck...
# 70  top cute 7 10 year old neice world justify put...
# 73              good fabric scratchy see thru get pay
# 77           shoes excalty pic show web site kind use
# 79     actually send back cause size run really small
# 80  shoe cute thought would picture side short nea...
# 81      poor quality fall apart seam also really long
# 83  see description make italy careful make india ...
# 85                   cheap seam be not sew way return
# 86  photo quite deceive suit make cheap polyester ...
